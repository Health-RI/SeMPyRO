# %% [markdown]
# # Pushing metadata to an FDP

# %% [markdown]
# This notebook can be used to manually push DCAT concepts according to the Health-RI Core v2 to a FAIR Data Point.
# If you are looking for interactive explanations, please see the 'Documentation' notebooks.
#
# **Prerequisites:** To execute this notebook in full one needs to have a running FAIR Data Point (FDP) instance with an active write access account.
# This notebook is written for the reference implementation, FAIR Data Point version 1.16 with the [Health-RI Core v2 SHACL shapes](https://github.com/Health-RI/health-ri-metadata/tree/develop/Formalisation(shacl)/Core/FairDataPointShape).

# %% [markdown]
# ## Imports and setup

# %%
from typing import List, Union
from pprint import pprint

from rdflib import URIRef, DCTERMS
from pydantic import AnyHttpUrl, Field, field_validator

from getpass import getpass
import dateutil.parser as parser

from fairclient.fdpclient import FDPClient

from sempyro import LiteralField
from sempyro.hri_dcat import (
    HRICatalog, 
    HRIDataset, 
    HRIVCard, 
    HRIAgent, 
    HRIDistribution,
    HRIDataService,
    HRIDatasetSeries,
    GeonovumLicences,
    DatasetStatus,
    DistributionStatus
)
from sempyro.time import PeriodOfTime
from sempyro.dcat import AccessRights, DCATCatalogRecord, Attribution, Relationship
from sempyro.dqv import QualityCertificate
from sempyro.utils.validator_functions import force_literal_field
from sempyro.spdx import Checksum
from sempyro.prov import Activity

from datetime import datetime
from sempyro.adms import Identifier
# Out:
# /Users/alexanderharms/.pyenv/versions/sempyro310/lib/python3.10/site-packages/pydantic/_internal/_generate_schema.py:502: UserWarning: [<class 'pydantic.networks.AnyHttpUrl'>] is not a Python type (it may be an instance of an object), Pydantic will allow any object with no validation since we cannot even enforce that the input is an instance of the given type. To get rid of this error wrap the type with `pydantic.SkipValidation`.
#   warn(

# %%
# fdp_base=input("Enter base link to FDP: ").rstrip("/")
# username=input("Enter username: ")
# password = getpass(prompt="Password: ")
fdp_base="http://localhost:8081"
username="albert.einstein@example.com"
password = "password"

fdp_client = FDPClient(base_url=fdp_base, username=username, password=password)

# %%
class FDPCatalog(HRICatalog):
    is_part_of: [AnyHttpUrl] = Field(
        description="Link to parent object", 
        json_schema_extra={
            "rdf_term": DCTERMS.isPartOf, 
            "rdf_type": "uri"
        })

class FDPDatasetSeries(HRIDatasetSeries):
    is_part_of: [AnyHttpUrl] = Field(
        description="Link to parent object", 
        json_schema_extra={
            "rdf_term": DCTERMS.isPartOf, 
            "rdf_type": "uri"
        })

# %% [markdown]
# ## Test objects

# %%
test_vcard = HRIVCard(
        hasEmail="mailto:data-access-committee@xumc.nl",
        formatted_name="Data Access Committee of the x UMC")
test_agent = HRIAgent(
        name=[LiteralField(value="Academic Medical Center")],
        identifier=["https://ror.org/05wg1m734"],
        homepage=URIRef("https://www.xumc.nl"),
        mbox="mailto:data-access-committee@xumc.nl"
    )
test_datetime = parser.isoparse("2024-07-01T11:11:11")
test_periodoftime = PeriodOfTime(
    start_date=LiteralField(value="2024-07-01T11:11:11Z", datatype="xsd:dateTime"),
    end_date=LiteralField(value="2024-07-01T11:11:11Z", datatype="xsd:dateTime")
)
test_uri = URIRef("http://www.example.com")

### 

test_catalog = FDPCatalog(
    title=[
        LiteralField(value="Test catalog", language="en")
    ],
    description=[
        LiteralField(value="Test catalog description", language="en")
    ],
    contact_point= test_vcard,
    publisher= test_agent,
    dataset=[],
    is_part_of=[URIRef(fdp_base)],
)



test_dataset = HRIDataset(
    contact_point=test_vcard,
    creator=[test_agent],
    description=[LiteralField(value="Test dataset description.")],
    release_date=test_datetime,
    identifier="https://www.example.com/dataset/ZLOYOJ",
    modification_date=parser.isoparse("2024-06-04T13:36:10.246Z"),
    publisher=test_agent,
    theme=[URIRef("http://publications.europa.eu/resource/authority/data-theme/HEAL")],
    title=[LiteralField(value="Test dataset")],
    distribution=[],
    access_rights=AccessRights.restricted,
    keyword=['example'],
    applicable_legislation=["http://data.europa.eu/eli/reg/2025/327/oj"])

test_datasetseries = FDPDatasetSeries(
    title=[
        LiteralField(value="Example Dataset Series title")
    ],
    description=[
        LiteralField(value="Example Dataset Series description")
    ],
    contact_point=[test_vcard],
    is_part_of=[URIRef(test_dataset.identifier)],
)

test_dataservice = HRIDataService(
    title=[
        LiteralField(value="Test Data Service Title")
    ],
    description=[
        LiteralField(value="Test Data Service Description")
    ],
    endpoint_description=LiteralField(value="Example Data Service Endpoint Description"),
    contact_point= test_vcard,
    access_rights=AccessRights.restricted,
    endpoint_url="https://www.example.com/dataservice/1",
    identifier="www.example.com/dataservice/test1",
    license=GeonovumLicences.niet_open,
    publisher= test_agent,
    theme=[URIRef("http://publications.europa.eu/resource/authority/data-theme/HEAL")],
)

test_distribution = HRIDistribution(
    title=[
        LiteralField(value="CSV-distribution of the questionnaire data of the Personalised RISk-based MAmmascreening Study (PRISMA)")
    ],
    description=[
        LiteralField(value="CSV file containing the questionnaire data of the PRISMA study")
    ],
    access_url=URIRef("https://example.com/dataset/PRISMA/questionnaire.csv"),
    media_type=URIRef("https://www.iana.org/assignments/media-types/text/csv"),
    byte_size=4096,
    license=URIRef("https://definities.geostandaarden.nl/dcat-ap-nl/id/waardelijst/licenties/niet_open"),
    rights="https://www.example.com/contracts/definitely_a_real_DPA.pdf",
    format=URIRef("http://publications.europa.eu/resource/authority/file-type/CSV"))

test_identifier = Identifier(
    notation = LiteralField(value="identification"),
    schema_agency = LiteralField(value="agency")
)

# %%
test_catalog_record = test_catalog.to_graph(URIRef(f"https://www.example.com/catalog/test1"))
test_catalog_fdp_url = fdp_client.create_and_publish(resource_type="catalog", metadata=test_catalog_record)
print(test_catalog_fdp_url)

test_dataservice_record = test_dataservice.to_graph(subject=URIRef(test_dataservice.identifier))
test_dataservice_record.add((
    URIRef(test_dataservice.identifier), 
    DCTERMS.isPartOf, 
    URIRef(f"{test_catalog_fdp_url}")
))
test_dataservice_fdp_url = fdp_client.create_and_publish(resource_type="dataservice", metadata=test_dataservice_record)

print(test_dataservice_fdp_url)


test_catalogrecord = DCATCatalogRecord(
    modification_date=test_datetime,
    primary_topic=test_catalog_fdp_url
)
test_catalogrecord_graph = test_catalogrecord.to_graph(subject=URIRef(f"https://www.example.com/catalog/test1"))
# Out:
# http://localhost:8081/catalog/18dbbe6f-7b0b-4654-92e8-2a096a2e87f3
# http://localhost:8081/dataservice/55354747-9d7d-4289-892d-811acacfa30f

# %% [markdown]
# ## Catalog

# %%
# Create a class instance with the same data
fdp_catalog = FDPCatalog(
    title=[
        LiteralField(value="Inflammatory Bowel Disease catalogue", language="en")
    ],
    description=[
        LiteralField(value="This catalogue describes the core metadata of AUMC Inflammatory Bowel Disease datasets", language="en")
    ],
    contact_point= test_vcard,
    publisher= test_agent,
    is_part_of=[URIRef(fdp_base)],
    dataset=[test_dataset],
    creator=[test_agent],
    service=[test_dataservice],
    catalog=[test_catalog],
    #catalog=[test_uri],
    applicable_legislation=["http://data.europa.eu/eli/reg/2025/327/oj"],
    has_part=[URIRef("http://localhost:8081/catalog/61ffda03-bcfc-4b21-a92f-f3e930870188")],
    geographical_coverage=[URIRef("http://publications.europa.eu/resource/authority/country/NLD")],
    homepage=URIRef("http://www.example.org"),
    license=URIRef("https://definities.geostandaarden.nl/dcat-ap-nl/id/waardelijst/licenties/niet_open"),
    modification_date=test_datetime,
    catalog_record=[test_catalogrecord],
    release_date=test_datetime,
    rights="https://www.example.com/contracts/definitely_a_real_DPA.pdf",
    temporal_coverage=[test_periodoftime],
    themes=[URIRef("http://publications.europa.eu/resource/authority/data-theme/HEAL")]
)

fdp_catalog_record = fdp_catalog.to_graph(URIRef(f"https://www.example.com/catalog/1"))
print(fdp_catalog_record.serialize())
# Out:
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix ns1: <http://data.europa.eu/r5r/> .
# @prefix v: <http://www.w3.org/2006/vcard/ns#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://www.example.com/catalog/1> a dcat:Catalog ;
#     ns1:applicableLegislation <http://data.europa.eu/eli/reg/2025/327/oj> ;
#     dcterms:creator [ a foaf:Agent ;
#             dcterms:identifier "https://ror.org/05wg1m734" ;
#             foaf:homepage <https://www.xumc.nl/> ;
#             foaf:mbox <mailto:data-access-committee@xumc.nl> ;
#             foaf:name "Academic Medical Center" ] ;
#     dcterms:description "This catalogue describes the core metadata of AUMC Inflammatory Bowel Disease datasets"@en ;
#     dcterms:hasPart <http://localhost:8081/catalog/61ffda03-bcfc-4b21-a92f-f3e930870188> ;
#     dcterms:isPartOf <http://localhost:8081> ;
#     dcterms:issued "2024-07-01T11:11:11"^^xsd:dateTime ;
#     dcterms:license <https://definities.geostandaarden.nl/dcat-ap-nl/id/waardelijst/licenties/niet_open> ;
#     dcterms:modified "2024-07-01T11:11:11"^^xsd:dateTime ;
#     dcterms:publisher [ a foaf:Agent ;
#             dcterms:identifier "https://ror.org/05wg1m734" ;
#             foaf:homepage <https://www.xumc.nl/> ;
#             foaf:mbox <mailto:data-access-committee@xumc.nl> ;
#             foaf:name "Academic Medical Center" ] ;
#     dcterms:rights <https://www.example.com/contracts/definitely_a_real_DPA.pdf> ;
#     dcterms:spatial <http://publications.europa.eu/resource/authority/country/NLD> ;
#     dcterms:temporal [ a dcterms:PeriodOfTime ;
#             dcat:endDate "2024-07-01T11:11:11+00:00"^^xsd:dateTime ;
#             dcat:startDate "2024-07-01T11:11:11+00:00"^^xsd:dateTime ] ;
#     dcterms:title "Inflammatory Bowel Disease catalogue"@en ;
#     dcat:catalog [ a dcat:Catalog ;
#             dcterms:description "Test catalog description"@en ;
#             dcterms:isPartOf <http://localhost:8081> ;
#             dcterms:publisher [ a foaf:Agent ;
#                     dcterms:identifier "https://ror.org/05wg1m734" ;
#                     foaf:homepage <https://www.xumc.nl/> ;
#                     foaf:mbox <mailto:data-access-committee@xumc.nl> ;
#                     foaf:name "Academic Medical Center" ] ;
#             dcterms:title "Test catalog"@en ;
#             dcat:contactPoint [ a v:Kind ;
#                     v:fn "Data Access Committee of the x UMC" ;
#                     v:hasEmail <mailto:data-access-committee@xumc.nl> ] ] ;
#     dcat:contactPoint [ a v:Kind ;
#             v:fn "Data Access Committee of the x UMC" ;
#             v:hasEmail <mailto:data-access-committee@xumc.nl> ] ;
#     dcat:dataset [ a dcat:Dataset ;
#             ns1:applicableLegislation <http://data.europa.eu/eli/reg/2025/327/oj> ;
#             dcterms:accessRights <http://publications.europa.eu/resource/authority/access-right/RESTRICTED> ;
#             dcterms:creator [ a foaf:Agent ;
#                     dcterms:identifier "https://ror.org/05wg1m734" ;
#                     foaf:homepage <https://www.xumc.nl/> ;
#                     foaf:mbox <mailto:data-access-committee@xumc.nl> ;
#                     foaf:name "Academic Medical Center" ] ;
#             dcterms:description "Test dataset description." ;
#             dcterms:identifier "https://www.example.com/dataset/ZLOYOJ" ;
#             dcterms:issued "2024-07-01T11:11:11"^^xsd:dateTime ;
#             dcterms:modified "2024-06-04T13:36:10.246000+00:00"^^xsd:dateTime ;
#             dcterms:publisher [ a foaf:Agent ;
#                     dcterms:identifier "https://ror.org/05wg1m734" ;
#                     foaf:homepage <https://www.xumc.nl/> ;
#                     foaf:mbox <mailto:data-access-committee@xumc.nl> ;
#                     foaf:name "Academic Medical Center" ] ;
#             dcterms:title "Test dataset" ;
#             dcat:contactPoint [ a v:Kind ;
#                     v:fn "Data Access Committee of the x UMC" ;
#                     v:hasEmail <mailto:data-access-committee@xumc.nl> ] ;
#             dcat:keyword "example" ;
#             dcat:theme <http://publications.europa.eu/resource/authority/data-theme/HEAL> ] ;
#     dcat:record [ a dcat:CatalogRecord ;
#             dcterms:modified "2024-07-01T11:11:11"^^xsd:dateTime ;
#             foaf:primaryTopic <http://localhost:8081/catalog/18dbbe6f-7b0b-4654-92e8-2a096a2e87f3> ] ;
#     dcat:service [ a dcat:DataService ;
#             dcterms:accessRights <http://publications.europa.eu/resource/authority/access-right/RESTRICTED> ;
#             dcterms:description "Test Data Service Description" ;
#             dcterms:identifier "www.example.com/dataservice/test1" ;
#             dcterms:license <https://definities.geostandaarden.nl/dcat-ap-nl/id/waardelijst/licenties/niet_open> ;
#             dcterms:publisher [ a foaf:Agent ;
#                     dcterms:identifier "https://ror.org/05wg1m734" ;
#                     foaf:homepage <https://www.xumc.nl/> ;
#                     foaf:mbox <mailto:data-access-committee@xumc.nl> ;
#                     foaf:name "Academic Medical Center" ] ;
#             dcterms:title "Test Data Service Title" ;
#             dcat:contactPoint [ a v:Kind ;
#                     v:fn "Data Access Committee of the x UMC" ;
#                     v:hasEmail <mailto:data-access-committee@xumc.nl> ] ;
#             dcat:endpointDescription "Example Data Service Endpoint Description" ;
#             dcat:endpointURL <https://www.example.com/dataservice/1> ;
#             dcat:theme <http://publications.europa.eu/resource/authority/data-theme/HEAL> ] ;
#     dcat:themeTaxonomy <http://publications.europa.eu/resource/authority/data-theme/HEAL> ;
#     foaf:homepage <http://www.example.org/> .

# %%
catalog_fdp_url = fdp_client.create_and_publish(resource_type="catalog", metadata=fdp_catalog_record)
print(catalog_fdp_url)
# Out:
# http://localhost:8081/catalog/6e0f8ca6-9a65-4ba8-b960-613efa724f87

# %% [markdown]
# ## Dataset

# %%
test_attribution = Attribution(
    agent=test_agent,
    role=test_uri
)

test_relationship = Relationship(
    had_role = [test_uri],
    relation = [test_uri]
)

test_quality = QualityCertificate(
    target = test_uri,
    body = test_uri
)

test_activity = Activity(
    generated = [test_uri],
    qualifiedAssociation = [test_uri],
    wasAssociatedWith = test_uri,
    wasEndedBy = test_uri,
    qualifiedUsage = [test_uri],
    used = test_uri,
    invalidated = [test_uri]
)

hri_dataset = HRIDataset(
    contact_point=test_vcard,
    creator=[test_agent],
    description=[LiteralField(value=
                              "The primary aim of the PRISMA study was to investigate the potential value of risk-tailored versus "
                              "traditional breast cancer screening protocols in the Netherlands. Data collection took place between "
                              "2014-2019, resulting in ∼67,000 mammograms, ∼38,000 surveys, ∼10,000 blood samples and ∼600 saliva "
                              "samples.")],
    release_date=test_datetime,
    identifier="https://www.example.com/dataset/ZLOYOJ",
    modification_date=test_datetime,
    publisher=test_agent,
    theme=[URIRef("http://publications.europa.eu/resource/authority/data-theme/HEAL")],
    title=[LiteralField(value="Questionnaire data of the Personalised RISk-based MAmmascreening Study (PRISMA)")],
    distribution=[test_distribution],
    access_rights=URIRef("http://publications.europa.eu/resource/authority/access-right/RESTRICTED"),
    keyword=['example'],
    applicable_legislation=["http://data.europa.eu/eli/reg/2025/327/oj"],
    analytics=[test_distribution],
    code_values=[test_uri],
    coding_system=[test_uri],
    conforms_to=[test_uri],
    frequency=test_uri,
    geographical_coverage=[test_uri],
    has_version=[test_uri],
    health_theme=[test_uri],
    in_series=[test_datasetseries],
    is_referenced_by=[test_uri],
    language=[test_uri],
    legal_basis=[test_uri],
    maximum_typical_age=99,
    minimum_typical_age=87,
    number_of_records=500,
    number_of_unique_individuals=2,
    other_identifier=[test_identifier],
    personal_data=[test_uri],
    population_coverage=LiteralField(value="Adults aged 18–65 diagnosed with type 2 diabetes in the Netherlands between 2015 and 2020"),
    purpose=[test_uri],
    qualified_attribution=[test_attribution],
    qualified_relation = [test_relationship],
    quality_annotation = [test_quality],
    retention_period=test_periodoftime,
    sample=[test_distribution],
    source=[URIRef(test_dataset.identifier)],
    status=DatasetStatus.develop, 
    temporal_coverage=[test_periodoftime],
    temporal_resolution=LiteralField(value="P1Y", datatype="xsd:duration"),
    type=[test_uri],
    version="Version 1",
    version_notes=["This is version 1"],
    # was_generated_by=[test_activity]
    was_generated_by=[test_uri]
)

fdp_dataset_record = hri_dataset.to_graph(subject=URIRef(hri_dataset.identifier))
print(fdp_dataset_record.serialize())
# Out:
# @prefix adms: <http://www.w3.org/ns/adms#> .
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix dqv: <http://www.w3.org/ns/dqv#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix ns1: <http://healthdataportal.eu/ns/health#> .
# @prefix ns2: <http://www.w3.org/ns/oa#> .
# @prefix ns3: <https://w3id.org/dpv#> .
# @prefix ns4: <http://data.europa.eu/r5r/> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
# @prefix v: <http://www.w3.org/2006/vcard/ns#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://www.example.com/dataset/ZLOYOJ> a dcat:Dataset ;
#     ns4:applicableLegislation <http://data.europa.eu/eli/reg/2025/327/oj> ;
#     ns1:analytics [ a dcat:Distribution ;
#             dcterms:description "CSV file containing the questionnaire data of the PRISMA study" ;
#             dcterms:format <http://publications.europa.eu/resource/authority/file-type/CSV> ;
#             dcterms:license <https://definities.geostandaarden.nl/dcat-ap-nl/id/waardelijst/licenties/niet_open> ;
#             dcterms:rights <https://www.example.com/contracts/definitely_a_real_DPA.pdf> ;
#             dcterms:title "CSV-distribution of the questionnaire data of the Personalised RISk-based MAmmascreening Study (PRISMA)" ;
#             dcat:accessURL <https://example.com/dataset/PRISMA/questionnaire.csv> ;
#             dcat:byteSize 4096 ;
#             dcat:mediaType <https://www.iana.org/assignments/media-types/text/csv> ] ;
#     ns1:hasCodeValues <http://www.example.com/> ;
#     ns1:hasCodingSystem <http://www.example.com/> ;
#     ns1:healthTheme <http://www.example.com/> ;
#     ns1:maxTypicalAge "99"^^xsd:nonNegativeInteger ;
#     ns1:minTypicalAge "87"^^xsd:nonNegativeInteger ;
#     ns1:numberOfRecords "500"^^xsd:nonNegativeInteger ;
#     ns1:numberOfUniqueIndividuals "2"^^xsd:nonNegativeInteger ;
#     ns1:populationCoverage "Adults aged 18–65 diagnosed with type 2 diabetes in the Netherlands between 2015 and 2020" ;
#     ns1:retentionPeriod [ a dcterms:PeriodOfTime ;
#             dcat:endDate "2024-07-01T11:11:11+00:00"^^xsd:dateTime ;
#             dcat:startDate "2024-07-01T11:11:11+00:00"^^xsd:dateTime ] ;
#     dcterms:accessRights <http://publications.europa.eu/resource/authority/access-right/RESTRICTED> ;
#     dcterms:accrualPeriodicity <http://www.example.com/> ;
#     dcterms:conformsTo <http://www.example.com/> ;
#     dcterms:creator [ a foaf:Agent ;
#             dcterms:identifier "https://ror.org/05wg1m734" ;
#             foaf:homepage <https://www.xumc.nl/> ;
#             foaf:mbox <mailto:data-access-committee@xumc.nl> ;
#             foaf:name "Academic Medical Center" ] ;
#     dcterms:description "The primary aim of the PRISMA study was to investigate the potential value of risk-tailored versus traditional breast cancer screening protocols in the Netherlands. Data collection took place between 2014-2019, resulting in ∼67,000 mammograms, ∼38,000 surveys, ∼10,000 blood samples and ∼600 saliva samples." ;
#     dcterms:hasVersion <http://www.example.com/> ;
#     dcterms:identifier "https://www.example.com/dataset/ZLOYOJ" ;
#     dcterms:isReferencedBy <http://www.example.com/> ;
#     dcterms:issued "2024-07-01T11:11:11"^^xsd:dateTime ;
#     dcterms:language <http://www.example.com/> ;
#     dcterms:modified "2024-07-01T11:11:11"^^xsd:dateTime ;
#     dcterms:publisher [ a foaf:Agent ;
#             dcterms:identifier "https://ror.org/05wg1m734" ;
#             foaf:homepage <https://www.xumc.nl/> ;
#             foaf:mbox <mailto:data-access-committee@xumc.nl> ;
#             foaf:name "Academic Medical Center" ] ;
#     dcterms:source <https://www.example.com/dataset/ZLOYOJ> ;
#     dcterms:spatial <http://www.example.com/> ;
#     dcterms:temporal [ a dcterms:PeriodOfTime ;
#             dcat:endDate "2024-07-01T11:11:11+00:00"^^xsd:dateTime ;
#             dcat:startDate "2024-07-01T11:11:11+00:00"^^xsd:dateTime ] ;
#     dcterms:title "Questionnaire data of the Personalised RISk-based MAmmascreening Study (PRISMA)" ;
#     dcterms:type <http://www.example.com/> ;
#     adms:identifier [ a adms:Identifier ;
#             skos:notation "identification" ;
#             adms:schemaAgency "agency" ] ;
#     adms:sample [ a dcat:Distribution ;
#             dcterms:description "CSV file containing the questionnaire data of the PRISMA study" ;
#             dcterms:format <http://publications.europa.eu/resource/authority/file-type/CSV> ;
#             dcterms:license <https://definities.geostandaarden.nl/dcat-ap-nl/id/waardelijst/licenties/niet_open> ;
#             dcterms:rights <https://www.example.com/contracts/definitely_a_real_DPA.pdf> ;
#             dcterms:title "CSV-distribution of the questionnaire data of the Personalised RISk-based MAmmascreening Study (PRISMA)" ;
#             dcat:accessURL <https://example.com/dataset/PRISMA/questionnaire.csv> ;
#             dcat:byteSize 4096 ;
#             dcat:mediaType <https://www.iana.org/assignments/media-types/text/csv> ] ;
#     adms:status <http://publications.europa.eu/resource/authority/dataset-status/DEVELOP> ;
#     adms:versionNotes "This is version 1" ;
#     dcat:contactPoint [ a v:Kind ;
#             v:fn "Data Access Committee of the x UMC" ;
#             v:hasEmail <mailto:data-access-committee@xumc.nl> ] ;
#     dcat:distribution [ a dcat:Distribution ;
#             dcterms:description "CSV file containing the questionnaire data of the PRISMA study" ;
#             dcterms:format <http://publications.europa.eu/resource/authority/file-type/CSV> ;
#             dcterms:license <https://definities.geostandaarden.nl/dcat-ap-nl/id/waardelijst/licenties/niet_open> ;
#             dcterms:rights <https://www.example.com/contracts/definitely_a_real_DPA.pdf> ;
#             dcterms:title "CSV-distribution of the questionnaire data of the Personalised RISk-based MAmmascreening Study (PRISMA)" ;
#             dcat:accessURL <https://example.com/dataset/PRISMA/questionnaire.csv> ;
#             dcat:byteSize 4096 ;
#             dcat:mediaType <https://www.iana.org/assignments/media-types/text/csv> ] ;
#     dcat:inSeries [ a dcat:DatasetSeries ;
#             dcterms:description "Example Dataset Series description" ;
#             dcterms:isPartOf <https://www.example.com/dataset/ZLOYOJ> ;
#             dcterms:title "Example Dataset Series title" ;
#             dcat:contactPoint [ a v:Kind ;
#                     v:fn "Data Access Committee of the x UMC" ;
#                     v:hasEmail <mailto:data-access-committee@xumc.nl> ] ] ;
#     dcat:keyword "example" ;
#     dcat:qualifiedRelation [ a dcat:Relationship ;
#             dcterms:relation <http://www.example.com/> ;
#             dcat:hadRole <http://www.example.com/> ] ;
#     dcat:temporalResolution "P1Y"^^xsd:duration ;
#     dcat:theme <http://publications.europa.eu/resource/authority/data-theme/HEAL> ;
#     dcat:version "Version 1" ;
#     dqv:hasQualityAnnotation [ a dqv:QualityCertificate ;
#             ns2:hasBody <http://www.example.com/> ;
#             ns2:hasTarget <http://www.example.com/> ] ;
#     prov:qualifiedAttribution [ a prov:Activity ;
#             dcat:hadRole <http://www.example.com/> ;
#             prov:agent [ a foaf:Agent ;
#                     dcterms:identifier "https://ror.org/05wg1m734" ;
#                     foaf:homepage <https://www.xumc.nl/> ;
#                     foaf:mbox <mailto:data-access-committee@xumc.nl> ;
#                     foaf:name "Academic Medical Center" ] ] ;
#     prov:wasGeneratedBy <http://www.example.com/> ;
#     ns3:hasLegalBasis <http://www.example.com/> ;
#     ns3:hasPersonalData <http://www.example.com/> ;
#     ns3:hasPurpose <http://www.example.com/> .

# %%
fdp_dataset_record.add((
    URIRef(hri_dataset.identifier), 
    DCTERMS.isPartOf, 
    URIRef(catalog_fdp_url)
))
dataset_fdp_url = fdp_client.create_and_publish(resource_type="dataset", metadata=fdp_dataset_record)

print(dataset_fdp_url)
# Out:
# http://localhost:8081/dataset/11ad1bdd-29e3-4323-b397-48c0e051e83c

# %% [markdown]
# ## Distribution

# %%
test_checksum = Checksum(
    algorithm=test_uri,
    checksum_value=LiteralField(value="000000", datatype='xsd:hexBinary')
)
hri_distribution = HRIDistribution(
    title=[
        LiteralField(value="CSV-distribution of the questionnaire data of the Personalised RISk-based MAmmascreening Study (PRISMA)")
    ],
    description=[
        LiteralField(value="CSV file containing the questionnaire data of the PRISMA study")
    ],
    access_url=URIRef("https://example.com/dataset/PRISMA/questionnaire.csv"),
    media_type=URIRef("https://www.iana.org/assignments/media-types/text/csv"),
    byte_size=4096,
    license=URIRef("https://definities.geostandaarden.nl/dcat-ap-nl/id/waardelijst/licenties/niet_open"),
    rights="https://www.example.com/contracts/definitely_a_real_DPA.pdf",
    format=URIRef("http://publications.europa.eu/resource/authority/file-type/CSV"),
    access_service=test_dataservice,
    applicable_legislation=[test_uri],
    checksum=test_checksum,
    compression_format=test_uri,
    documentation=[test_uri],
    download_url=test_uri,
    language=[test_uri],
    linked_schemas=[test_uri],
    modification_date=test_datetime,
    packaging_format=test_uri,
    release_date=test_datetime,
    retention_period=[test_periodoftime],
    status=DistributionStatus.develop,
    temporal_resolution=LiteralField(value="P1Y", datatype="xsd:duration")
)
access_url_str = str(hri_distribution.access_url)
distribution_uri = URIRef(f"{hri_dataset.identifier}/distribution/{access_url_str.split('/')[-1]}")
fdp_distribution_record = hri_distribution.to_graph(subject=distribution_uri)
print(fdp_distribution_record.serialize())
# Out:
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix ns1: <http://www.w3.org/ns/adms#> .
# @prefix ns2: <http://data.europa.eu/r5r/> .
# @prefix spdx: <http://spdx.org/rdf/terms#> .
# @prefix v: <http://www.w3.org/2006/vcard/ns#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://www.example.com/dataset/ZLOYOJ/distribution/questionnaire.csv> a dcat:Distribution ;
#     ns2:applicableLegislation <http://www.example.com/> ;
#     dcterms:accrualPeriodicity [ a dcterms:PeriodOfTime ;
#             dcat:endDate "2024-07-01T11:11:11+00:00"^^xsd:dateTime ;
#             dcat:startDate "2024-07-01T11:11:11+00:00"^^xsd:dateTime ] ;
#     dcterms:conformsTo <http://www.example.com/> ;
#     dcterms:description "CSV file containing the questionnaire data of the PRISMA study" ;
#     dcterms:format <http://publications.europa.eu/resource/authority/file-type/CSV> ;
#     dcterms:issued "2024-07-01T11:11:11"^^xsd:dateTime ;
#     dcterms:language <http://www.example.com/> ;
#     dcterms:license <https://definities.geostandaarden.nl/dcat-ap-nl/id/waardelijst/licenties/niet_open> ;
#     dcterms:modified "2024-07-01T11:11:11"^^xsd:dateTime ;
#     dcterms:rights <https://www.example.com/contracts/definitely_a_real_DPA.pdf> ;
#     dcterms:title "CSV-distribution of the questionnaire data of the Personalised RISk-based MAmmascreening Study (PRISMA)" ;
#     spdx:checksum [ a spdx:Checksum ;
#             spdx:algorithm <http://www.example.com/> ;
#             spdx:checksumValue "000000"^^xsd:hexBinary ] ;
#     ns1:status <http://publications.europa.eu/resource/authority/distribution-status/DEVELOP> ;
#     dcat:accessService [ a dcat:DataService ;
#             dcterms:accessRights <http://publications.europa.eu/resource/authority/access-right/RESTRICTED> ;
#             dcterms:description "Test Data Service Description" ;
#             dcterms:identifier "www.example.com/dataservice/test1" ;
#             dcterms:license <https://definities.geostandaarden.nl/dcat-ap-nl/id/waardelijst/licenties/niet_open> ;
#             dcterms:publisher [ a foaf:Agent ;
#                     dcterms:identifier "https://ror.org/05wg1m734" ;
#                     foaf:homepage <https://www.xumc.nl/> ;
#                     foaf:mbox <mailto:data-access-committee@xumc.nl> ;
#                     foaf:name "Academic Medical Center" ] ;
#             dcterms:title "Test Data Service Title" ;
#             dcat:contactPoint [ a v:Kind ;
#                     v:fn "Data Access Committee of the x UMC" ;
#                     v:hasEmail <mailto:data-access-committee@xumc.nl> ] ;
#             dcat:endpointDescription "Example Data Service Endpoint Description" ;
#             dcat:endpointURL <https://www.example.com/dataservice/1> ;
#             dcat:theme <http://publications.europa.eu/resource/authority/data-theme/HEAL> ] ;
#     dcat:accessURL <https://example.com/dataset/PRISMA/questionnaire.csv> ;
#     dcat:byteSize 4096 ;
#     dcat:compressFormat <http://www.example.com/> ;
#     dcat:downloadURL <http://www.example.com/> ;
#     dcat:mediaType <https://www.iana.org/assignments/media-types/text/csv> ;
#     dcat:packageFormat <http://www.example.com/> ;
#     dcat:spatialResolutionInMeters "P1Y"^^xsd:duration ;
#     foaf:page <http://www.example.com/> .

# %%
fdp_distribution_record.add((distribution_uri, DCTERMS.isPartOf, URIRef(f"{dataset_fdp_url}")))
distribution_fdp_url = fdp_client.create_and_publish(resource_type="distribution", metadata=fdp_distribution_record)

print(distribution_fdp_url)
# Out:
# http://localhost:8081/distribution/065ca01f-63f6-416c-82d2-05e6f8e99935

# %% [markdown]
# ## Data Service

# %%
hri_dataservice = HRIDataService(
    title=[
        LiteralField(value="Example Data Service Title")
    ],
    description=[
        LiteralField(value="Example Data Service Description")
    ],
    endpoint_description=LiteralField(value="Example Data Service Endpoint Description"),
    contact_point=test_vcard,
    access_rights=URIRef("http://publications.europa.eu/resource/authority/access-right/RESTRICTED"),
    endpoint_url="https://www.example.com/dataservice/1",
    identifier="www.example.com/dataservice/1",
    license=URIRef("https://definities.geostandaarden.nl/dcat-ap-nl/id/waardelijst/licenties/niet_open"),
    publisher=test_agent,
    theme=[URIRef("http://publications.europa.eu/resource/authority/data-theme/HEAL")],
    applicable_legislation=[test_uri],
    application_profile=[test_uri],
    creator=[test_agent],
    rights=[test_uri],
    format=[test_uri],
    hvd_category=[test_uri],
    keyword=["test"],
    landing_page=[test_uri],
    language=[test_uri],
    modification_date=test_datetime,
    other_identifier=[test_identifier],
    serves_dataset=[URIRef(test_dataset.identifier)]
)

# %%
fdp_dataservice_record = hri_dataservice.to_graph(subject=URIRef(hri_dataservice.identifier))
fdp_dataservice_record.add((
    URIRef(hri_dataservice.identifier), 
    DCTERMS.isPartOf, 
    URIRef(f"{catalog_fdp_url}")
))
dataservice_fdp_url = fdp_client.create_and_publish(resource_type="dataservice", metadata=fdp_dataservice_record)

print(dataservice_fdp_url)
# Out:
# http://localhost:8081/dataservice/0f9e0333-4c72-4794-854a-74fb6d1107f8

# %% [markdown]
# ## Dataset Series

# %%
fdp_datasetseries = FDPDatasetSeries(
    title=[
        LiteralField(value="Example Dataset Series title")
    ],
    description=[
        LiteralField(value="Example Dataset Series description")
    ],
    is_part_of=[URIRef(dataset_fdp_url)],
    applicable_legislation=[test_uri],
    contact_point=[test_vcard],
    frequency=test_uri,
    geographical_coverage=[test_uri],
    modification_date=test_datetime,
    publisher=test_agent,
    release_date=test_datetime,
    temporal_coverage=[test_periodoftime]
)
fdp_datasetseries_record = fdp_datasetseries.to_graph(URIRef(f"https://www.example.com/datasetseries/1"))
print(fdp_datasetseries_record.serialize())
# Out:
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix ns1: <http://data.europa.eu/r5r/> .
# @prefix v: <http://www.w3.org/2006/vcard/ns#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://www.example.com/datasetseries/1> a dcat:DatasetSeries ;
#     ns1:applicableLegislation <http://www.example.com/> ;
#     dcterms:accrualPeriodicity <http://www.example.com/> ;
#     dcterms:description "Example Dataset Series description" ;
#     dcterms:isPartOf <http://localhost:8081/dataset/11ad1bdd-29e3-4323-b397-48c0e051e83c> ;
#     dcterms:issued "2024-07-01T11:11:11"^^xsd:dateTime ;
#     dcterms:modified "2024-07-01T11:11:11"^^xsd:dateTime ;
#     dcterms:publisher [ a foaf:Agent ;
#             dcterms:identifier "https://ror.org/05wg1m734" ;
#             foaf:homepage <https://www.xumc.nl/> ;
#             foaf:mbox <mailto:data-access-committee@xumc.nl> ;
#             foaf:name "Academic Medical Center" ] ;
#     dcterms:spatial <http://www.example.com/> ;
#     dcterms:temporal [ a dcterms:PeriodOfTime ;
#             dcat:endDate "2024-07-01T11:11:11+00:00"^^xsd:dateTime ;
#             dcat:startDate "2024-07-01T11:11:11+00:00"^^xsd:dateTime ] ;
#     dcterms:title "Example Dataset Series title" ;
#     dcat:contactPoint [ a v:Kind ;
#             v:fn "Data Access Committee of the x UMC" ;
#             v:hasEmail <mailto:data-access-committee@xumc.nl> ] .

# %%
datasetseries_fdp_url = fdp_client.create_and_publish(resource_type="datasetseries", metadata=fdp_datasetseries_record)

print(datasetseries_fdp_url)
# Out:
# 400 : @prefix rsx: <http://rdf4j.org/shacl-extensions#> .
# @prefix rdf4j: <http://rdf4j.org/schema/rdf4j#> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix ldp: <http://www.w3.org/ns/ldp#> .
#
# [] a sh:ValidationReport;
#   sh:conforms false;
#   rdf4j:truncated false;
#   sh:result [ a sh:ValidationResult;
#       sh:focusNode <http://localhost:8081/datasetseries/7b49c7a3-cd98-4ba3-a17f-495b546036ac>;
#       rsx:shapesGraph rdf4j:SHACLShapeGraph;
#       sh:value [];
#       sh:resultPath dcterms:temporal;
#       sh:sourceConstraintComponent sh:NodeKindConstraintComponent;
#       sh:resultSeverity sh:Violation;
#       sh:sourceShape <http://data.health-ri.nl/core/p2/DatasetSeriesShape#dct:temporal>
#     ] .
#
# <http://data.health-ri.nl/core/p2/DatasetSeriesShape#dct:temporal> a sh:PropertyShape;
#   sh:path dcterms:temporal;
#   sh:nodeKind sh:IRI .
# Traceback (most recent call last):
#   File "/Users/alexanderharms/.pyenv/versions/sempyro310/lib/python3.10/site-packages/fairclient/basicclient.py", line 61, in _call_method
#     response.raise_for_status()
#   File "/Users/alexanderharms/.pyenv/versions/sempyro310/lib/python3.10/site-packages/requests/models.py", line 1024, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 400 Client Error:  for url: http://localhost:8081/datasetseries
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 datasetseries_fdp_url = fdp_client.create_and_publish(resource_type="datasetseries", metadata=fdp_datasetseries_record)
#       3 print(datasetseries_fdp_url)
#
# File ~/.pyenv/versions/sempyro310/lib/python3.10/site-packages/fairclient/fdpclient.py:166, in FDPClient.create_and_publish(self, resource_type, metadata)
#     151 def create_and_publish(self, resource_type: str, metadata: Graph) -> URIRef:
#     152     """Creates and publishes a record in the FDP
#     153
#     154     Parameters
#    (...)
#     164         URI of (subject of) published dataset
#     165     """
# --> 166     post_response = self.post_serialized(resource_type=resource_type, metadata=metadata)
#     168     # FDP will return a 201 status code with the new identifier of the published record
#     169     fdp_subject = URIRef(post_response.headers["Location"])
#
# File ~/.pyenv/versions/sempyro310/lib/python3.10/site-packages/fairclient/fdpclient.py:111, in FDPClient.post_serialized(self, resource_type, metadata)
#     109 path = f"{self.base_url}/{resource_type}"
#     110 logger.debug("Posting metadata to %s", path)
# --> 111 return self.post(path=path, data=metadata.serialize(format="turtle"))
#
# File ~/.pyenv/versions/sempyro310/lib/python3.10/site-packages/fairclient/basicclient.py:72, in BasicAPIClient.post(self, path, params, data, **kwargs)
#      71 def post(self, path: str, params: dict | None = None, data=None, **kwargs) -> Response:
# ---> 72     return self._call_method("POST", path, params=params, data=data, **kwargs)
#
# File ~/.pyenv/versions/sempyro310/lib/python3.10/site-packages/fairclient/basicclient.py:61, in BasicAPIClient._call_method(self, method, path, params, data, json)
#      50 response = self.session.request(
#      51     method,
#      52     url,
#    (...)
#      57     timeout=self.timeout,
#      58 )
#      60 try:
# ---> 61     response.raise_for_status()
#      62 except HTTPError as e:
#      63     logger.exception("%d %s: %s", e.response.status_code, e.response.reason, e.response.text)
#
# File ~/.pyenv/versions/sempyro310/lib/python3.10/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error:  for url: http://localhost:8081/datasetseries
